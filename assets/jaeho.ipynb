# %%
import pyterrier as pt
import os
import pandas as pd
import psutil
import time
import pandas as pd
import requests

# %%
data = [
    ("001", "Lilac Wildfire 2017"),
    ("002", "Cranston Wildfire 2018"),
    ("003", "Holy Wildfire 2018"),
    ("004", "Hurricane Florence 2018"),
    ("005", "2018 Maryland Flood"),
    ("006", "Saddleridge Wildfire 2019"),
    ("007", "Hurricane Laura 2020"),
    ("008", "Hurricane Sally 2020"),
    ("009", "Beirut Explosion 2020"),
    ("010", "Houston Explosion 2020"),
    ("011", "Rutherford TN Floods 2020"),
    ("012", "TN Derecho 2020"),
    ("013", "Edenville Dam Fail 2020"),
    ("014", "Hurricane Dorian 2019"),
    ("015", "Kincade Wildfire 2019"),
    ("016", "Easter Tornado Outbreak 2020"),
    ("017", "Tornado Outbreak April 2020"),
    ("018", "Tornado Outbreak March 2020"),
]

# Create DataFrame
event_df = pd.DataFrame(data, columns=["ID", "EventName"])

# %%
def get_eventsMeta(eventNoList='001', days=100):
    def getDaysForEventNo(eventNo):

        # We will download a file containing the day list for an event
        url = "http://trecis.org/CrisisFACTs/CrisisFACTS-"+eventNo+".requests.json"

        # Download the list and parse as JSON
        dayList = requests.get(url).json()

        return dayList

    eventNoList = eventNoList.split(',')

    eventsMeta = {}

    for eventNo in eventNoList: # for each event
        
        dailyInfo = getDaysForEventNo(eventNo) # get the list of days
        eventsMeta[eventNo]= dailyInfo[:days]

    return eventsMeta

# %%
event_list = '001,002,003,004,005,006,007,008,009,010,011,012,013,014,015,016,017,018'

eventsMeta = get_eventsMeta(eventNoList=event_list)

# %%
os.environ['IR_DATASETS_HOME'] = '../'

dataset_df = pd.DataFrame()
queries_df = pd.DataFrame()

for eventId, dailyInfo in eventsMeta.items():

    queries = pd.read_csv(f'../crisisfacts/{eventId}.csv')
    queries['ID'] = eventId
    queries_df = pd.concat([queries_df, queries], ignore_index=True)

    for thisDay in dailyInfo:
        ir_dataset_id = "crisisfacts/%s/%s" % (eventId, thisDay["dateString"])
        # print(ir_dataset_id, " processing")  

        pyTerrierDataset = pt.get_dataset(f'irds:{ir_dataset_id}')


        # dataset = pd.DataFrame(pyTerrierDataset.get_corpus_iter(), columns=['docno', 'text', 'unix_timestamp'])
        dataset = pd.DataFrame(pyTerrierDataset.get_corpus_iter())
        dataset['ID'] = eventId
        dataset['date'] = thisDay['dateString']

        dataset_df = pd.concat([dataset_df, dataset], ignore_index=True)

dataset_df = dataset_df.merge(event_df, on='ID')
queries_df = queries_df.merge(event_df, on='ID')
# Out:
# crisisfacts/001/2017-12-07 documents: 7288it [00:00, 15512.83it/s]
# crisisfacts/001/2017-12-08 documents: 19231it [00:01, 16882.00it/s]
# crisisfacts/001/2017-12-09 documents: 5839it [00:00, 31402.28it/s]
# crisisfacts/001/2017-12-10 documents: 4407it [00:00, 9098.99it/s]
# crisisfacts/001/2017-12-11 documents: 3394it [00:00, 32268.92it/s]
# crisisfacts/001/2017-12-12 documents: 2805it [00:00, 38046.31it/s]
# 2  CrisisFACTS-001  The county of San Diego has opened a Local Ass...
# 3  CrisisFACTS-001  The center is at the Vista branch library on 7...
# 4  CrisisFACTS-001  Homeowners also will be able to get informatio...
#
#                                               source source_type  \
# 0  {'url': 'http://www.sandiegouniontribune.com/n...        News
# 1  {'url': 'http://www.sandiegouniontribune.com/n...        News
# 2  {'url': 'http://www.sandiegouniontribune.com/n...        News
# 3  {'url': 'http://www.sandiegouniontribune.com/n...        News
# 4  {'url': 'http://www.sandiegouniontribune.com/n...        News
#
#    unix_timestamp                     docno   ID        date
# 0      1512604800  CrisisFACTS-001-News-5-0  001  2017-12-07
# 1      1512604800  CrisisFACTS-001-News-5-1  001  2017-12-07
# 2      1512604800  CrisisFACTS-001-News-5-2  001  2017-12-07
# 3      1512604800  CrisisFACTS-001-News-5-3  001  2017-12-07
# 4      1512604800  CrisisFACTS-001-News-5-4  001  2017-12-07

# %%
queries_df.head()
# Out:
#                    query_id                                   text  \
# 0  CrisisFACTS-General-q001                   Have airports closed
# 1  CrisisFACTS-General-q002                   Have railways closed
# 2  CrisisFACTS-General-q003  Have water supplied been contaminated
# 3  CrisisFACTS-General-q004       How many firefighters are active
# 4  CrisisFACTS-General-q005           How many people are affected
#
#        indicative_terms trecis_category_mapping         event_id  \
# 0        airport closed          Report-Factoid  CrisisFACTS-001
# 1           rail closed          Report-Factoid  CrisisFACTS-001
# 2          water supply  Report-EmergingThreats  CrisisFACTS-001
# 3  firefighters on-duty          Report-Factoid  CrisisFACTS-001
# 4             evacuated          Report-Factoid  CrisisFACTS-001
#
#            event_title                   event_dataset  \
# 0  Lilac Wildfire 2017  2017_12_07_lilac_wildfire.2017
# 1  Lilac Wildfire 2017  2017_12_07_lilac_wildfire.2017
# 2  Lilac Wildfire 2017  2017_12_07_lilac_wildfire.2017
# 3  Lilac Wildfire 2017  2017_12_07_lilac_wildfire.2017
# 4  Lilac Wildfire 2017  2017_12_07_lilac_wildfire.2017
#
#                                    event_description    event_trecis_id  \
# 0  The Lilac Fire was a fire that burned in north...  TRECIS-CTIT-H-092
# 1  The Lilac Fire was a fire that burned in north...  TRECIS-CTIT-H-092
# 2  The Lilac Fire was a fire that burned in north...  TRECIS-CTIT-H-092
# 3  The Lilac Fire was a fire that burned in north...  TRECIS-CTIT-H-092
# 4  The Lilac Fire was a fire that burned in north...  TRECIS-CTIT-H-092
#
#   event_type                                 event_url   ID  \
# 0   Wildfire  https://en.wikipedia.org/wiki/Lilac_Fire  001
# 1   Wildfire  https://en.wikipedia.org/wiki/Lilac_Fire  001
# 2   Wildfire  https://en.wikipedia.org/wiki/Lilac_Fire  001
# 3   Wildfire  https://en.wikipedia.org/wiki/Lilac_Fire  001
# 4   Wildfire  https://en.wikipedia.org/wiki/Lilac_Fire  001
#
#              EventName
# 0  Lilac Wildfire 2017
# 1  Lilac Wildfire 2017
# 2  Lilac Wildfire 2017
# 3  Lilac Wildfire 2017
# 4  Lilac Wildfire 2017
